# %% [markdown]
# <a href="https://colab.research.google.com/github/winesther23/CMPSC-132-Project-2/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing the File

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
Counties_Vote = pd.read_csv('/content/drive/My Drive/Datasets/Project_2/Voting-Counties.csv')

# %%
df = pd.DataFrame(Counties_Vote)

# %%
df.head(10)
# Out:
#        county        county_full  county_fips state_id    state_name  \
# 0      Sumter      Sumter County      12119.0       FL       Florida
# 1       Stark       Stark County      38089.0       ND  North Dakota
# 2      Warren      Warren County      34041.0       NJ    New Jersey
# 3  Shenandoah  Shenandoah County      51171.0       VA      Virginia
# 4      Newton      Newton County      29145.0       MO      Missouri
# 5    Culpeper    Culpeper County      51047.0       VA      Virginia
# 6    Marshall    Marshall County      19127.0       IA          Iowa
# 7    Randolph    Randolph County      29175.0       MO      Missouri
# 8     Bandera     Bandera County      48019.0       TX         Texas
# 9      Martin      Martin County      12085.0       FL       Florida
#
#   Return Time      lat       lng  population pct_st_pop factor  VoteCast  \
# 0    20:05:00  28.7048  -82.0810    131832.0      0.60%     1%   0.20836
# 1    20:05:24  46.8107 -102.6551     32989.0      2.90%     3%   0.30308
# 2    20:05:44  40.8572  -74.9973    109739.0      1.20%    -3%   0.23850
# 3    20:06:01  38.8583  -78.5708     44337.0      1.30%     3%   0.23479
# 4    20:06:12  36.9055  -94.3393     59019.0      1.00%     3%   0.35988
# 5    20:06:32  38.4860  -77.9558     52822.0      1.50%     3%   0.23479
# 6    20:06:40  42.0358  -92.9988     40049.0      2.80%    -2%   0.22748
# 7    20:07:02  39.4401  -92.4971     24652.0      0.40%     3%   0.35988
# 8    20:07:12  29.7472  -99.2463     21182.0      0.10%     4%   0.18838
# 9    20:07:29  27.0775  -80.4315    159399.0      0.70%     1%   0.20836
#
#      Votes  RR Votes  BB Votes Return Date Return Time.1  0.000277778  \
# 0  27469.0   15957.0   11512.0   11/5/2024      20:05:00          NaN
# 1   9998.0    6208.0    3790.0   11/5/2024      20:05:24          NaN
# 2  26173.0    9679.0   16494.0   11/5/2024      20:05:44          NaN
# 3  10410.0    8032.0    2378.0   11/5/2024      20:06:01          NaN
# 4  21240.0   11337.0    9903.0   11/5/2024      20:06:12          NaN
# 5  12402.0    8434.0    3968.0   11/5/2024      20:06:32          NaN
# 6   9110.0    2433.0    6677.0   11/5/2024      20:06:40          NaN
# 7   8872.0    3592.0    5280.0   11/5/2024      20:07:02          NaN
# 8   3990.0    1655.0    2335.0   11/5/2024      20:07:12          NaN
# 9  33213.0   11633.0   21580.0   11/5/2024      20:07:29          NaN
#
#      Color Winner
# 0  magenta     RR
# 1  magenta     RR
# 2    green     BB
# 3  magenta     RR
# 4  magenta     RR
# 5  magenta     RR
# 6    green     BB
# 7    green     BB
# 8    green     BB
# 9    green     BB

# %% [markdown]
# #Task 1 (Collect Votes cast from counties in the County_Votes.csv and determine the sum of votes for candidate in each state)

# %%
#Grouping all the counties under their state and summing up the total votes, BB votes, and RR votes for each state

Total_Votes_Per_Candidate = df.groupby(['state_name'])[['Votes', 'BB Votes', 'RR Votes']].sum()

# %%
print(Total_Votes_Per_Candidate)
# Out:
#                           Votes   BB Votes   RR Votes
# state_name
# Montana                  330915.0
# Nebraska                 448490.0
# Nevada                   855405.0
# New Hampshire            315858.0
# New Jersey              2205887.0
# New Mexico               582004.0
# New York                5508624.0
# North Carolina          3173329.0
# North Dakota             235455.0
# Ohio                    2806481.0
# Oklahoma                 883684.0
# Oregon                  1807571.0
# Pennsylvania            4217716.0
# Rhode Island             339356.0
# South Carolina          1052671.0
# South Dakota             235481.0
# Tennessee               1482795.0
# Texas                   5508977.0
# Utah                     770997.0
# Vermont                  242935.0
# Virginia                2024924.0
# Washington              2423437.0
# West Virginia            593696.0
# Wisconsin               1947726.0
# Wyoming                  132302.0
# Name: Total, dtype: float64

# %% [markdown]
# #Task 2 (Convert the votes to % win for Buggs Bunny and for Road Runner in each state.)

# %%
#Calculating the percentage by diving the candidates votes by the total amount of votes. After that, Multiplying it by 100 to get it into percentage form

Total_Votes_Per_Candidate['BB_Percentage'] = (Total_Votes_Per_Candidate['BB Votes'] / Total_Votes_Per_Candidate['Total']) * 100
Total_Votes_Per_Candidate['RR_Percentage'] = (Total_Votes_Per_Candidate['RR Votes'] / Total_Votes_Per_Candidate['Total']) * 100

# %%
print(Total_Votes_Per_Candidate[['BB_Percentage', 'RR_Percentage']])
# Out:
#                       BB_Percentage  RR_Percentage
# state_name
# Alabama                   51.036252      48.963748
# Alaska                    42.981085      57.018915
# Arizona                   47.583374      52.416626
# Arkansas                  49.133636      50.866364
# California                54.109044      45.890956
# Colorado                  48.062059      51.937941
# Connecticut               52.498568      47.501432
# Delaware                  51.720899      48.279101
# District of Columbia      47.184433      52.815567
# Florida                   47.334744      52.665256
# Georgia                   53.710631      46.289369
# Hawaii                    65.832179      34.167821
# Idaho                     48.528859      51.471141
# Illinois                  50.251391      49.748609
# Indiana                   46.330030      53.669970
# Iowa                      46.585479      53.414521
# Kansas                    45.515331      54.484669
# Kentucky                  46.173336      53.826664
# Louisiana                 53.470285      46.529715
# Maine                     63.077666      36.922334
# Maryland                  45.819188      54.180812
# Massachusetts             48.544999      51.455001
# Michigan                  56.965622      43.034378
# Minnesota                 48.083574      51.916426
# Mississippi               50.564059      49.435941
# Missouri                  49.145125      50.854875
# Montana                   50.003777      49.996223
# Nebraska                  53.225936      46.774064
# Nevada                    49.214583      50.785417
# New Hampshire             60.435386      39.564614
# New Jersey                50.479059      49.520941
# New Mexico                38.150597      61.849403
# New York                  51.402964      48.597036
# North Carolina            43.766278      56.233722
# North Dakota              41.006137      58.993863
# Ohio                      48.938261      51.061739
# Oklahoma                  46.483471      53.516529
# Oregon                    45.373321      54.626679
# Pennsylvania              53.102793      46.897207
# Rhode Island              57.766770      42.233230
# South Carolina            44.696966      55.303034
# South Dakota              45.062659      54.937341
# Tennessee                 43.194170      56.805830
# Texas                     45.341195      54.658805
# Utah                      45.000564      54.999436
# Vermont                   50.446827      49.553173
# Virginia                  44.964157      55.035843
# Washington                52.378089      47.621911
# West Virginia             51.757970      48.242030
# Wisconsin                 51.916491      48.083509
# Wyoming                   46.752128      53.247872

# %%
Total_Votes_Per_Candidate
# Out:
#                           Votes   BB Votes   RR Votes      Total  \
# state_name
# Alabama               1395992.0   712462.0   683530.0  1395992.0
# Florida                   47.334744      52.665256
# Georgia                   53.710631      46.289369
# Hawaii                    65.832179      34.167821
# Idaho                     48.528859      51.471141
# Illinois                  50.251391      49.748609
# Indiana                   46.330030      53.669970
# Iowa                      46.585479      53.414521
# Kansas                    45.515331      54.484669
# Kentucky                  46.173336      53.826664
# Louisiana                 53.470285      46.529715
# Maine                     63.077666      36.922334
# Maryland                  45.819188      54.180812
# Massachusetts             48.544999      51.455001
# Michigan                  56.965622      43.034378
# Minnesota                 48.083574      51.916426
# Mississippi               50.564059      49.435941
# Missouri                  49.145125      50.854875
# Montana                   50.003777      49.996223
# Nebraska                  53.225936      46.774064
# Nevada                    49.214583      50.785417
# New Hampshire             60.435386      39.564614
# New Jersey                50.479059      49.520941
# New Mexico                38.150597      61.849403
# New York                  51.402964      48.597036
# North Carolina            43.766278      56.233722
# North Dakota              41.006137      58.993863
# Ohio                      48.938261      51.061739
# Oklahoma                  46.483471      53.516529
# Oregon                    45.373321      54.626679
# Pennsylvania              53.102793      46.897207
# Rhode Island              57.766770      42.233230
# South Carolina            44.696966      55.303034
# South Dakota              45.062659      54.937341
# Tennessee                 43.194170      56.805830
# Texas                     45.341195      54.658805
# Utah                      45.000564      54.999436
# Vermont                   50.446827      49.553173
# Virginia                  44.964157      55.035843
# Washington                52.378089      47.621911
# West Virginia             51.757970      48.242030
# Wisconsin                 51.916491      48.083509
# Wyoming                   46.752128      53.247872

# %% [markdown]
# #Task 3 (Determine who won the popular vote)

# %%
#Getting the total amount of votes for each candidate

total_rr_votes = df['RR Votes'].sum()
total_bb_votes = df['BB Votes'].sum()

# %%
#Using ternary operator to check who won the popular vote

popular_vote_winner = "Road Runner" if total_rr_votes > total_bb_votes else "Buggs Bunny"
print(f'The candidate with the popular vote is {popular_vote_winner} with Road Runner Votes at {total_rr_votes} and Bug Bunny votes at {total_bb_votes}')
# Out:
# The candidate with the popular vote is Road Runner with Road Runner Votes at 86354224.0 and Bug Bunny votes at 85374974.0

# %% [markdown]
# #Task 4 (Read in the info from State-Info.csv)

# %%
#Reading in the State Info file to get the electoral votes

State_Info = pd.read_csv('/content/drive/MyDrive/Datasets/Project_2/State-Info.csv')

# %%
#Merging the two created datasets so that the computer doesn't get confused
#Better and easier usage if it was within the same dataset

df1 = Total_Votes_Per_Candidate.merge(State_Info[['Location', 'Electoral Votes']], left_on='state_name', right_on='Location', how='left')

# %%
#Printing df1 to see if everything merged over

df1.head(10)
# Out:
#        Votes   BB Votes   RR Votes      Total  BB_Percentage  RR_Percentage  \
# 0  1395992.0   712462.0   683530.0  1395992.0      51.036252      48.963748
# 1   204013.0    87687.0   116326.0   204013.0      42.981085      57.018915
# 2  1900439.0   904293.0   996146.0  1900439.0      47.583374      52.416626
# 3   838100.0   411789.0   426311.0   838100.0      49.133636      50.866364
# 4  8876664.0  4803078.0  4073586.0  8876664.0      54.109044      45.890956
# 5  1891311.0   909003.0   982308.0  1891311.0      48.062059      51.937941
# 6   878403.0   461149.0   417254.0   878403.0      52.498568      47.501432
# 7   298071.0   154165.0   143906.0   298071.0      51.720899      48.279101
# 8   163111.0    76963.0    86148.0   163111.0      47.184433      52.815567
# 9  4507803.0  2133757.0  2374046.0  4507803.0      47.334744      52.665256
#
#                Location  Electoral Votes
# 0               Alabama              9.0
# 1                Alaska              3.0
# 2               Arizona             11.0
# 3              Arkansas              6.0
# 4            California             54.0
# 5              Colorado             10.0
# 6           Connecticut              7.0
# 7              Delaware              3.0
# 8  District of Columbia              3.0
# 9               Florida             30.0

# %% [markdown]
# #Task 5 (Award Electoral Votes for each state to the winner of the state with the highest number of votes for either BB or RR)

# %%
#Creating the column, State Winner, to go through each column and see who won each state
#Lambda is used as we will be only using the function once

df1['State_Winner'] = df1.apply(lambda x: 'BB' if x['BB Votes'] > x['RR Votes'] else 'RR', axis=1)
State_Winner = df1['State_Winner']

# %%
#Creating the two electoral votes column and awards them the electoral votes

df1['Electoral_Votes_Won_BB'] = df1.apply(lambda x: x['Electoral Votes'] if x['State_Winner'] == 'BB' else 0, axis=1)
df1['Electoral_Votes_Won_RR'] = df1.apply(lambda x: x['Electoral Votes'] if x['State_Winner'] == 'RR' else 0, axis=1)

# %%
df1.head(10)
# Out:
#        Votes   BB Votes   RR Votes      Total  BB_Percentage  RR_Percentage  \
# 0  1395992.0   712462.0   683530.0  1395992.0      51.036252      48.963748
# 1   204013.0    87687.0   116326.0   204013.0      42.981085      57.018915
# 2  1900439.0   904293.0   996146.0  1900439.0      47.583374      52.416626
# 3   838100.0   411789.0   426311.0   838100.0      49.133636      50.866364
# 4  8876664.0  4803078.0  4073586.0  8876664.0      54.109044      45.890956
# 5  1891311.0   909003.0   982308.0  1891311.0      48.062059      51.937941
# 6   878403.0   461149.0   417254.0   878403.0      52.498568      47.501432
# 7   298071.0   154165.0   143906.0   298071.0      51.720899      48.279101
# 8   163111.0    76963.0    86148.0   163111.0      47.184433      52.815567
# 9  4507803.0  2133757.0  2374046.0  4507803.0      47.334744      52.665256
#
#                Location  Electoral Votes State_Winner  Electoral_Votes_Won_BB  \
# 0               Alabama              9.0           BB                     9.0
# 1                Alaska              3.0           RR                     0.0
# 2               Arizona             11.0           RR                     0.0
# 3              Arkansas              6.0           RR                     0.0
# 4            California             54.0           BB                    54.0
# 5              Colorado             10.0           RR                     0.0
# 6           Connecticut              7.0           BB                     7.0
# 7              Delaware              3.0           BB                     3.0
# 8  District of Columbia              3.0           RR                     0.0
# 9               Florida             30.0           RR                     0.0
#
#    Electoral_Votes_Won_RR
# 0                     0.0
# 1                     3.0
# 2                    11.0
# 3                     6.0
# 4                     0.0
# 5                    10.0
# 6                     0.0
# 7                     0.0
# 8                     3.0
# 9                    30.0

# %% [markdown]
# #Task 6 (Determine who won the Electoral Vote tally)

# %%
#Summing the Electoral Votes for each candidate to see who won the race

total_electoral_votes_bb = df1['Electoral_Votes_Won_BB'].sum()
total_electoral_votes_rr = df1['Electoral_Votes_Won_RR'].sum()

# %%
print("Total Electoral Votes for BB:", total_electoral_votes_bb)
print("Total Electoral Votes for RR:", total_electoral_votes_rr)
# Out:
# Total Electoral Votes for BB: 252.0
# Total Electoral Votes for RR: 286.0

# %% [markdown]
# #Task 7 (Accept the State ID and list all of the summary info for the state with winner, totals and electoral votes awarded.)

# %%
#Reindexing df1 to make it look more organized and easier to read each data column
df1["State_id"] = State_Info['Postal Abbreviation']

df1 = df1.reindex(columns=['Location', 'State_id', 'Votes', 'BB Votes', 'RR Votes', 'BB_Percentage', 'RR_Percentage', 'Electoral Votes', 'State_Winner', 'Electoral_Votes_Won_BB', 'Electoral_Votes_Won_RR'])

# %%
df1.head(10)
# Out:
#                Location State_id      Votes   BB Votes   RR Votes  \
# 0               Alabama       AL  1395992.0   712462.0   683530.0
# 1                Alaska       AK   204013.0    87687.0   116326.0
# 2               Arizona       AZ  1900439.0   904293.0   996146.0
# 3              Arkansas       AR   838100.0   411789.0   426311.0
# 4            California       CA  8876664.0  4803078.0  4073586.0
# 5              Colorado       CO  1891311.0   909003.0   982308.0
# 6           Connecticut       CT   878403.0   461149.0   417254.0
# 7              Delaware       DE   298071.0   154165.0   143906.0
# 8  District of Columbia       DC   163111.0    76963.0    86148.0
# 9               Florida       FL  4507803.0  2133757.0  2374046.0
#
#    BB_Percentage  RR_Percentage  Electoral Votes State_Winner  \
# 0      51.036252      48.963748              9.0           BB
# 1      42.981085      57.018915              3.0           RR
# 2      47.583374      52.416626             11.0           RR
# 3      49.133636      50.866364              6.0           RR
# 4      54.109044      45.890956             54.0           BB
# 5      48.062059      51.937941             10.0           RR
# 6      52.498568      47.501432              7.0           BB
# 7      51.720899      48.279101              3.0           BB
# 8      47.184433      52.815567              3.0           RR
# 9      47.334744      52.665256             30.0           RR
#
#    Electoral_Votes_Won_BB  Electoral_Votes_Won_RR
# 0                     9.0                     0.0
# 1                     0.0                     3.0
# 2                     0.0                    11.0
# 3                     0.0                     6.0
# 4                    54.0                     0.0
# 5                     0.0                    10.0
# 6                     7.0                     0.0
# 7                     3.0                     0.0
# 8                     0.0                     3.0
# 9                     0.0                    30.0

# %%
#Adding in the user input and showing the summary of each state

enter_state_id = input("Enter the State ID: ")

state_counties = df1[df1['State_id'] == enter_state_id]

print(state_counties.head())
# Out:
# Enter the State ID: AL
#   Location State_id      Votes  BB Votes  RR Votes  BB_Percentage  \
# 0  Alabama       AL  1395992.0  712462.0  683530.0      51.036252
#
#    RR_Percentage  Electoral Votes State_Winner  Electoral_Votes_Won_BB  \
# 0      48.963748              9.0           BB                     9.0
#
#    Electoral_Votes_Won_RR
# 0                     0.0

# %% [markdown]
# #Task 8 (Print a summary chart)

# %%
#Printing as a csv file to show the summary of the race

df1.to_csv("ElectionRace.CSV", index=False)

# %% [markdown]
# #Task 9

# %%
#Used StackOverflow and ChatGPT to get an idea of how to code this
#Allowing the user to enter a date to see live results of the election

from datetime import datetime

report_time_input = input("Enter the report time (YYYY-MM-DD): ")
report_time = datetime.strptime(report_time_input, "%Y-%m-%d")

report = f"""
Report Time: {report_time_input}
Popular Vote Leader: {popular_vote_winner} (BB Votes: {total_bb_votes}, RR Votes: {total_rr_votes})
Electoral Vote Leader: {State_Winner} (BB Electoral Votes: {total_electoral_votes_bb}, RR Electoral Votes: {total_electoral_votes_rr})
"""

print(report)
# Out:
# Enter the report time (YYYY-MM-DD): 1968-02-13
#
# Report Time: 1968-02-13
# Popular Vote Leader: Road Runner (BB Votes: 85374974.0, RR Votes: 86354224.0)
# Electoral Vote Leader: 0     BB
# 1     RR
# 2     RR
# 3     RR
# 4     BB
# 5     RR
# 6     BB
# 7     BB
# 8     RR
# 9     RR
# 10    BB
# 11    BB
# 12    RR
# 13    BB
# 14    RR
# 15    RR
# 16    RR
# 17    RR
# 18    BB
# 19    BB
# 20    RR
# 21    RR
# 22    BB
# 23    RR
# 24    BB
# 25    RR
# 26    BB
# 27    BB
# 28    RR
# 29    BB
# 30    BB
# 31    RR
# 32    BB
# 33    RR
# 34    RR
# 35    RR
# 36    RR
# 37    RR
# 38    BB
# 39    BB
# 40    RR
# 41    RR
# 42    RR
# 43    RR
# 44    RR
# 45    BB
# 46    RR
# 47    BB
# 48    BB
# 49    BB
# 50    RR
# Name: State_Winner, dtype: object (BB Electoral Votes: 252.0, RR Electoral Votes: 286.0)

# %% [markdown]
# #Extra Credit 2 (Using matplotlib, plot all counties with a dot showing if Buggs Bunny (green) or Road Runner (magenta) was the winner)

# %%
#Plotting all the counties to see who won depending on the color

import matplotlib.pyplot as plt

#Have to create the lambda function again as it is in a different dataset
df['Winner'] = df.apply(lambda x: 'BB' if x['BB Votes'] > x['RR Votes'] else 'RR', axis=1)
df['Color'] = df['Winner'].map({'BB': 'green', 'RR': 'magenta'})

plt.scatter(x=df['lng'], y=df['lat'], c=df['Color'])
plt.show()

# %% [markdown]
# #Extra Credit 3 (Plot the state’s county results for the State ID entered)

# %%
#Getting User Input
enter_state_id = input("Enter the State ID: ")

# Filter for the specified State ID
state_counties = df[df['state_id'] == enter_state_id]

# Check the structure of the data to see what can be plotted
print(state_counties.head())

#Inputting all information and showing the plot of each county for each state
plt.figure(figsize=(10, 6))
plt.bar(state_counties['county'], state_counties['Votes'], color='skyblue')
plt.title(f'County Results for State ID: {enter_state_id}')
plt.xlabel('County')
plt.ylabel('Votes')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Enter the State ID: AL
#         county       county_full  county_fips state_id state_name Return Time  \
# 73       Lamar      Lamar County       1075.0       AL    Alabama    20:22:06
# 142     Wilcox     Wilcox County       1131.0       AL    Alabama    20:35:58
# 147  Covington  Covington County       1039.0       AL    Alabama    20:36:49
# 173      Coosa      Coosa County       1037.0       AL    Alabama    20:42:47
# 185       Hale       Hale County       1065.0       AL    Alabama    20:44:39
#
#          lat      lng  population pct_st_pop factor  VoteCast    Votes  \
# 73   33.7791 -88.0970     13885.0      1.90%    -2%   0.27764   3855.0
# 142  31.9893 -87.3082     10441.0      1.40%    -2%   0.27764   2899.0
# 147  31.2485 -86.4513     37542.0      5.10%    -2%   0.27764  10423.0
# 173  32.9362 -86.2477     10329.0      1.40%    -2%   0.27764   2868.0
# 185  32.7627 -87.6291     14742.0      2.00%    -2%   0.27764   4093.0
#
#      RR Votes  BB Votes Return Date Return Time.1  0.000277778    Color Winner
# 73     1037.0    2818.0   11/5/2024      20:22:06          NaN    green     BB
# 142    1549.0    1350.0   11/5/2024      20:35:58          NaN  magenta     RR
# 147    5416.0    5007.0   11/5/2024      20:36:49          NaN  magenta     RR
# 173    1948.0     920.0   11/5/2024      20:42:47          NaN  magenta     RR
# 185    1809.0    2284.0   11/5/2024      20:44:39          NaN    green     BB
